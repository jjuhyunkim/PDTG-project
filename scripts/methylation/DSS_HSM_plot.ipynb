# %%
suppressPackageStartupMessages(library(DSS))
suppressPackageStartupMessages(library(bsseq))
options(warn=-1)
#options(warn=0) # use to turn warining back on.

# %%
chr=14
outDir="/data/Phillippy/projects/HG002_Masseq/09.methylation/steven_count"

# %%
dat1.1 = paste0("/vf/users/Phillippy/projects/HG002_Masseq/09.methylation/steven_count/steven.ont.hg002.mat.toCHM13.chr",as.character(chr),".dmr.bed")
dat1.2 = paste0("/vf/users/Phillippy/projects/HG002_Masseq/09.methylation/steven_count/steven.ont.hg002.pat.toCHM13.chr",as.character(chr),".dmr.bed")
dat2.1 = paste0("/vf/users/Phillippy/projects/HG002_Masseq/09.methylation/steven_count/steven.hifi.hg002.mat.toCHM13.chr",as.character(chr),".dmr.bed")
dat2.2 = paste0("/vf/users/Phillippy/projects/HG002_Masseq/09.methylation/steven_count/steven.hifi.hg002.pat.toCHM13.chr",as.character(chr),".dmr.bed")

# %%
dat1.1 = read.table(file.path(dat1.1), header=TRUE)
dat1.2 = read.table(file.path(dat1.2), header=TRUE)
dat2.1 = read.table(file.path(dat2.1), header=TRUE)
dat2.2 = read.table(file.path(dat2.2), header=TRUE)

# %%
BSobj = makeBSseqData( list(dat1.1, dat1.2, dat2.1 , dat2.2),
      c('mat_ont','pat_ont','mat_hifi','pat_hifi'))
BSobj
# Out:
# An object of type 'BSseq' with
#   994599 methylation loci
#   4 samples
# has not been smoothed
# All assays are in-memory

# %%
dmrs = read.table(paste0(outDir, "/dmr.hifi_ont.hap.chr",chr,".tsv"),
                  header = TRUE)
head(dmrs)
# Out:
#   chr   start    end      length nCG meanMethy1 meanMethy2 diff.Methy areaStat
# 1 chr14 95058929 95062646 3718   202 0.1824853  0.7803179  -0.5978326 -3786.555
# 2 chr14 62834940 62836105 1166    64 0.8683054  0.1221050   0.7462004  2023.475
# 3 chr14 14920153 14921027  875    56 0.8379001  0.1236121   0.7142881  1781.099
# 4 chr14 24887939 24888898  960    39 0.1022361  0.9271293  -0.8248933 -1676.539
# 5 chr14 99780608 99781879 1272   116 0.5596331  0.1179652   0.4416678  1288.834
# 6 chr14 13614016 13616240 2225   187 0.7294081  0.9259210  -0.1965129 -1262.379

# %%
start=68059695

# %%
dmrs[dmrs['start'] == start,]
# Out:
#    chr   start    end      length nCG meanMethy1 meanMethy2 diff.Methy
# 15 chr14 68059695 68060539 845    37  0.1073458  0.7342426  -0.6268968
#    areaStat
# 15 -753.2221

# %%
showOneDMR(dmrs[(dmrs$start == start),], BSobj)
# Out:
# Plot with title “pat_hifi”

# %%
sessionInfo()
# Out:
# R version 4.3.1 (2023-06-16)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Rocky Linux 8.7 (Green Obsidian)
#
# Matrix products: default
# BLAS/LAPACK: /gpfs/gsfs11/users/kimj75/anaconda3/envs/pacbioDNA/lib/libopenblasp-r0.3.23.so;  LAPACK version 3.11.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: America/New_York
# tzcode source: system (glibc)
#
# attached base packages:
# [1] parallel  stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] DSS_2.48.0                  bsseq_1.36.0
#  [3] SummarizedExperiment_1.30.2 MatrixGenerics_1.12.3
#  [5] matrixStats_1.2.0           GenomicRanges_1.52.1
#  [7] GenomeInfoDb_1.36.1         IRanges_2.34.1
#  [9] S4Vectors_0.38.1            BiocParallel_1.34.2
# [11] Biobase_2.60.0              BiocGenerics_0.46.0
#
# loaded via a namespace (and not attached):
#  [1] rjson_0.2.21              rhdf5_2.44.0
#  [3] lattice_0.22-4            rhdf5filters_1.12.1
#  [5] vctrs_0.6.3               tools_4.3.1
#  [7] bitops_1.0-7              fansi_1.0.4
#  [9] R.oo_1.26.0               Matrix_1.6-1.1
# [11] data.table_1.15.2         BSgenome_1.68.0
# [13] sparseMatrixStats_1.12.2  uuid_1.1-1
# [15] lifecycle_1.0.3           GenomeInfoDbData_1.2.10
# [17] compiler_4.3.1            Rsamtools_2.16.0
# [19] Biostrings_2.68.1         munsell_0.5.0
# [21] repr_1.1.6                codetools_0.2-19
# [23] permute_0.9-7             htmltools_0.5.6
# [25] yaml_2.3.8                RCurl_1.98-1.12
# [27] pillar_1.9.0              crayon_1.5.2
# [29] R.utils_2.12.3            DelayedArray_0.26.7
# [31] limma_3.56.2              abind_1.4-5
# [33] gtools_3.9.5              locfit_1.5-9.9
# [35] digest_0.6.33             restfulr_0.0.15
# [37] splines_4.3.1             fastmap_1.1.1
# [39] grid_4.3.1                colorspace_2.1-0
# [41] cli_3.6.1                 S4Arrays_1.0.6
# [43] base64enc_0.1-3           XML_3.99-0.14
# [45] utf8_1.2.3                IRdisplay_1.1
# [47] DelayedMatrixStats_1.22.6 scales_1.2.1
# [49] IRkernel_1.3.2            XVector_0.40.0
# [51] pbdZMQ_0.3-9              R.methodsS3_1.8.2
# [53] HDF5Array_1.28.1          evaluate_0.21
# [55] BiocIO_1.10.0             rtracklayer_1.60.1
# [57] rlang_1.1.1               Rcpp_1.0.11
# [59] glue_1.6.2                jsonlite_1.8.7
# [61] R6_2.5.1                  Rhdf5lib_1.22.1
# [63] GenomicAlignments_1.36.0  zlibbioc_1.46.0
