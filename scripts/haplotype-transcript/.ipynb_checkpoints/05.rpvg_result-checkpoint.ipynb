# %% [markdown]
# # import modules

# %%
import pandas as pd
from Bio import SeqIO
from Bio import Entrez
from Bio.Blast import NCBIXML
from Bio.Blast import NCBIWWW
from Bio import ExPASy
import biomart

# %% [markdown]
# # load data

# %%
rpvg = "/data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/07.hg002v1.0.1/05.quantification/hg002v101.allGene.isoquantModel.rpvg_joint.txt"

# %%
rpvg_tab = pd.read_csv(rpvg, sep="\t")
rpvg_tab.head()
# Out:
#                          Name_1                        Name_2  ClusterID  \
# 0             TCONS_00020747_R1             TCONS_00020747_H1         20
# 1  transcript12583.chr10.nic_R1  transcript12583.chr10.nic_H1         20
# 2             TCONS_00020735_R1             TCONS_00020735_H1         20
# 3             TCONS_00020751_R1             TCONS_00020751_H1         20
# 4             TCONS_00020739_R1             TCONS_00020739_H1         20
#
#    HaplotypingProbability  ReadCount_1      TPM_1  ReadCount_2      TPM_2
# 0                     1.0     0.000000   0.000000      0.00000   0.000000
# 1                     1.0   400.482380  50.293997    233.34355  29.312355
# 2                     1.0    14.922362   6.534654      0.00000   0.000000
# 3                     1.0     0.000000   0.000000      0.00000   0.000000
# 4                     1.0     0.000000   0.000000      0.00000   0.000000

# %%
rpvg_tab[rpvg_tab['Name_2'] == '.']
# Out:
#                              Name_1 Name_2  ClusterID  HaplotypingProbability  \
# 16     transcript1930.chr20.nnic_R1      .        260                1.000000
# 17     transcript1926.chr20.nnic_R1      .        260                1.000000
# 18      transcript1946.chr20.nic_R1      .        260                1.000000
# 19      transcript1964.chr20.nic_R1      .        260                1.000000
# 20                TCONS_00118332_H1      .        260                1.000000
# ...                             ...    ...        ...                     ...
# 12817             TCONS_00149580_R1      .       1675                0.164640
# 12820             TCONS_00036484_H1      .       1675                0.082049
# 12821             TCONS_00036488_H1      .       1675                0.082049
# 12823             TCONS_00149578_R1      .       1675                0.164640
# 12825             TCONS_00149579_R1      .       1675                0.164640
#
#        ReadCount_1     TPM_1  ReadCount_2  TPM_2
# 16       15.921570  1.134495          0.0    0.0
# 17        0.000000  0.000000          0.0    0.0
# 18        0.000000  0.000000          0.0    0.0
# 19        0.000000  0.000000          0.0    0.0
# 20        0.000000  0.000000          0.0    0.0
# ...            ...       ...          ...    ...
# 12817     0.000000  0.000000          0.0    0.0
# 12820     0.133396  0.036683          0.0    0.0
# 12821     0.112752  0.030996          0.0    0.0
# 12823     0.000000  0.000000          0.0    0.0
# 12825     0.000000  0.000000          0.0    0.0
#
# [1952 rows x 8 columns]

# %%
tarpvg_tabb = rpvg_tab[rpvg_tab['Name_1'] != 'Unknown']
rpvg_tab_unproject = rpvg_tab[rpvg_tab['Name_2'] == '.']
rpvg_tab_unproject.head(3)
rpvg_tab = rpvg_tab[rpvg_tab['Name_2'] != '.']

# %% [markdown]
# # Table modification

# %%
# make transcript name
rpvg_tab['trans'] = rpvg_tab['Name_1'].str.replace('_R1','',regex=False)
rpvg_tab['trans'] = rpvg_tab['trans'].str.replace('_H1','',regex=True)
rpvg_tab['trans'] = rpvg_tab['trans'].str.replace('_H2','',regex=True)
rpvg_tab.head(2)
# Out:
#                          Name_1                        Name_2  ClusterID  \
# 0             TCONS_00020747_R1             TCONS_00020747_H1         20
# 1  transcript12583.chr10.nic_R1  transcript12583.chr10.nic_H1         20
#
#    HaplotypingProbability  ReadCount_1      TPM_1  ReadCount_2      TPM_2  \
# 0                     1.0      0.00000   0.000000      0.00000   0.000000
# 1                     1.0    400.48238  50.293997    233.34355  29.312355
#
#                        trans
# 0             TCONS_00020747
# 1  transcript12583.chr10.nic

# %% [raw]
# # Specify the BioMart dataset and attributes
# mart = "ENSEMBL_MART_ENSEMBL"
# dataset = "hsapiens_gene_ensembl"
# attributes = ["ensembl_transcript_id", "external_gene_name"]

# %%
trans_gene = pd.read_csv("/data/Phillippy/projects/HG002_Masseq/03.align/HG002_Bulk/01.mapped/chm13_2312_2/gtf/chm13v2.0.refseq_curated5.1.rCRS.chrEBV.combined.transcript-gene.pair",
                        sep='\t', header=None)
trans_gene.columns = ['trans','gene']
trans_gene.head(2)
# Out:
#             trans          gene
# 0  TCONS_00000001  LOC124905335
# 1  TCONS_00000002     LINC01409

# %%
rpvg_gene = rpvg_tab.merge(trans_gene, left_on="trans", right_on="trans", how = 'left')
rpvg_gene.head(3)
# Out:
#                          Name_1                        Name_2  ClusterID  \
# 0             TCONS_00020747_R1             TCONS_00020747_H1         20
# 1  transcript12583.chr10.nic_R1  transcript12583.chr10.nic_H1         20
# 2             TCONS_00020735_R1             TCONS_00020735_H1         20
#
#    HaplotypingProbability  ReadCount_1      TPM_1  ReadCount_2      TPM_2  \
# 0                     1.0     0.000000   0.000000      0.00000   0.000000
# 1                     1.0   400.482380  50.293997    233.34355  29.312355
# 2                     1.0    14.922362   6.534654      0.00000   0.000000
#
#                        trans     gene
# 0             TCONS_00020747  WASHC2A
# 1  transcript12583.chr10.nic      NaN
# 2             TCONS_00020735  WASHC2A

# %% [markdown]
# # Filtering highest probability within each isoform

# %%
idx = rpvg_gene.groupby(['trans'])['HaplotypingProbability'].transform(max) == rpvg_gene['HaplotypingProbability']

# %%
# select only one transcript with highest HaplotypingProbability
rpvg_gene['max'] = "N"
rpvg_gene.loc[idx,'max'] = "T"
rpvg_gene_max = rpvg_gene[rpvg_gene['max'] == "T"]
# del joint['max']

# %%
# remove transcripts that have multiple combinations with same HaplotypingProbability
dup = rpvg_gene_max.loc[rpvg_gene_max.duplicated(subset="trans", keep=False),'trans'].tolist()
rpvg_gene_max = rpvg_gene_max[~rpvg_gene_max.trans.isin(dup)]

# %%
rpvg_gene_max.shape
# Out:
# (7013, 11)

# %%
rpvg_gene_max.head(3)
# Out:
#                          Name_1                        Name_2  ClusterID  \
# 0             TCONS_00020747_R1             TCONS_00020747_H1         20
# 1  transcript12583.chr10.nic_R1  transcript12583.chr10.nic_H1         20
# 2             TCONS_00020735_R1             TCONS_00020735_H1         20
#
#    HaplotypingProbability  ReadCount_1      TPM_1  ReadCount_2      TPM_2  \
# 0                     1.0     0.000000   0.000000      0.00000   0.000000
# 1                     1.0   400.482380  50.293997    233.34355  29.312355
# 2                     1.0    14.922362   6.534654      0.00000   0.000000
#
#                        trans     gene max
# 0             TCONS_00020747  WASHC2A   T
# 1  transcript12583.chr10.nic      NaN   T
# 2             TCONS_00020735  WASHC2A   T

# %%
rpvg_gene_max.to_csv('/data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/07.hg002v1.0.1/05.quantification/hg002v101.allGene.isoquantModel.rpvg_joint.max.txt',
          sep='\t', index = None)

# %% [markdown]
# ### Make expression table by haplotypes

# %%
hap1 = rpvg_gene_max[['trans',"TPM_1"]]
hap2 = rpvg_gene_max[['trans',"TPM_2"]]
hapExp = hap1.merge(hap2, left_on = "trans", right_on = "trans")
hapExp.columns = ['transcript_id','hap1','hap2']

# %%
hapExp
# Out:
#                   transcript_id       hap1       hap2
# 0                TCONS_00020747   0.000000   0.000000
# 1     transcript12583.chr10.nic  50.293997  29.312355
# 2                TCONS_00020735   6.534654   0.000000
# 3                TCONS_00020751   0.000000   0.000000
# 4                TCONS_00020739   0.000000   0.000000
# ...                         ...        ...        ...
# 7008             TCONS_00037841   0.000000   0.000000
# 7009             TCONS_00037838   0.000000   0.000000
# 7010             TCONS_00037840   0.000000   0.000000
# 7011  transcript44779.chr11.nic   0.000000   0.000000
# 7012                    Unknown   0.000000   0.000000
#
# [7013 rows x 3 columns]

# %%
hapExp.to_csv('/data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/07.hg002v1.0.1/05.quantification/hg002v101.allGene.isoquantModel.rpvg_joint.max.hap.txt',
          sep='\t', index = None)

# %% [markdown]
# # Allele specific expression discovery

# %%
rpvg_gene_max["FC"] = rpvg_gene_max[["ReadCount_1", "ReadCount_2"]].max(axis=1) / rpvg_gene_max[["ReadCount_1", "ReadCount_2"]].min(axis=1)
rpvg_gene_max["MAX_value"] = rpvg_gene_max[["ReadCount_1", "ReadCount_2"]].max(axis=1)

# %% [markdown]
# # filter the result

# %%
rpvg_gene_max_filter = rpvg_gene_max[(rpvg_gene_max['ReadCount_1'] != 0 ) | (rpvg_gene_max['ReadCount_2'] != 0 )]

# %%
df = rpvg_gene_max_filter

# %%
import pandas as pd
import numpy as np

# Assuming df is your DataFrame
# Create a new column to check if "FC" column has infinity values
df['FC_is_inf'] = np.isinf(df['FC'])

# Define conditions
condition_1 = (df['FC_is_inf']) & (df['MAX_value'] > 10)
condition_2 = (df['FC'] > 2) & (df['MAX_value'] > 10)

# Use boolean indexing to select rows that meet either condition_1 or condition_2
selected_rows = df[condition_1 | condition_2]

# Drop the temporary column created for checking infinity values
selected_rows = selected_rows.drop(columns=['FC_is_inf'])
selected_rows = selected_rows.sort_values(by=['FC', 'MAX_value'], ascending=False)
# Out:
# /tmp/ipykernel_138690/513393006.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FC_is_inf'] = np.isinf(df['FC'])

# %%
selected_rows
# Out:
#                             Name_1                        Name_2  ClusterID  \
# 7634             TCONS_00019335_H1             TCONS_00019335_H2        114
# 4912             TCONS_00022257_H1             TCONS_00022257_H2         12
# 8331  transcript19906.chr10.nic_H1  transcript19906.chr10.nic_H2         28
# 4911             TCONS_00022247_H1             TCONS_00022247_H2         12
# 3201             TCONS_00020436_H1             TCONS_00020436_H2         65
# ...                            ...                           ...        ...
# 3571   transcript6166.chr9.nnic_H1   transcript6166.chr9.nnic_H2        310
# 2893             TCONS_00020768_H1             TCONS_00020768_H2        138
# 7168             TCONS_00019949_R1             TCONS_00019949_H1        443
# 8463             TCONS_00023461_H1             TCONS_00023461_H2        462
# 8418             TCONS_00024356_H1             TCONS_00024356_H2        250
#
#       HaplotypingProbability  ReadCount_1       TPM_1  ReadCount_2  \
# 7634                     1.0  1427.151300  408.168440     0.000000
# 4912                     1.0  1082.466900  372.891020     0.000000
# 8331                     1.0   709.998390  172.740280     0.000000
# 4911                     1.0     0.000000    0.000000   591.636730
# 3201                     1.0   558.579400  118.216390     0.000000
# ...                      ...          ...         ...          ...
# 3571                     1.0    84.807390    7.034318    41.859096
# 2893                     1.0    72.399289   13.411878    36.078672
# 7168                     1.0    44.712496   28.115304    22.287304
# 8463                     1.0    20.967747    7.453056    42.032253
# 8418                     1.0    16.298647    3.818694    32.653720
#
#            TPM_2                      trans     gene max        FC  \
# 7634    0.000000             TCONS_00019335     FBH1   T       inf
# 4912    0.000000             TCONS_00022257    LZTS2   T       inf
# 8331    0.000000  transcript19906.chr10.nic      NaN   T       inf
# 4911  208.720580             TCONS_00022247    LZTS2   T       inf
# 3201    0.000000             TCONS_00020436  WASHC2C   T       inf
# ...          ...                        ...      ...  ..       ...
# 3571    3.800299   transcript6166.chr9.nnic      NaN   T  2.026021
# 2893    6.691859             TCONS_00020768   ASAH2B   T  2.006706
# 7168   14.004438             TCONS_00019949    BAMBI   T  2.006187
# 8463   14.940507             TCONS_00023461    ASB13   T  2.004615
# 8418    7.650609             TCONS_00024356   ZNF248   T  2.003462
#
#         MAX_value
# 7634  1427.151300
# 4912  1082.466900
# 8331   709.998390
# 4911   591.636730
# 3201   558.579400
# ...           ...
# 3571    84.807390
# 2893    72.399289
# 7168    44.712496
# 8463    42.032253
# 8418    32.653720
#
# [432 rows x 13 columns]

# %%
selected_rows.to_csv('/data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/07.hg002v1.0.1/05.quantification/FC.maxVlaue.txt',
          sep='\t', index = None)

# %% [markdown]
# ## Methylation match

# %%
selectFile="/data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/07.hg002v1.0.1/05.quantification/FC.maxVlaue.txt"
gtfFile="/data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/07.hg002v1.0.1/00.references/chm13.hg002_read.isoquantModel.squanti3_rescued.gtf"

# %% [raw]
# grep -w -f <(cut -f 9 /data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/07.hg002v1.0.1/05.quantification/FC.maxVlaue.txt) <(awk '$3=="transcript" {print $1,$4,$5,$10,$12}' OFS="\t" /data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/07.hg002v1.0.1/00.references/chm13.hg002_read.isoquantModel.squanti3_rescued.gtf) | sed -e 's/chm13#0#chr/chr/' > /data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/07.hg002v1.0.1/05.quantification/FC.maxVlaue.startSite.txt

# %% [markdown]
# ## Intersect Known allele speccific expression

# %%
# alleleSpecific = pd.read_csv("/data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/06.1kg_EURnonCEU/allelicInbalnce.trans.csv")
# alleleSpecific = pd.read_csv("/data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/06.1kg_EURnonCEU/allelespecificGene.list")
alleleSpecific = pd.read_csv("/data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/06.1kg_EURnonCEU/geneImprint.list")
alleleSpecific['state'] = 'allelespecific'
alleleSpecific.head(3)
# Out:
#        gene           state
# 0  NDUFA4P1  allelespecific
# 1      GFI1  allelespecific
# 2    DIRAS3  allelespecific

# %%
alleleSpecific.shape
# Out:
# (275, 2)

# %%
joint_rpvg_knownASE = rpvg_gene_max_filter.merge(alleleSpecific, left_on="gene", right_on="gene", how = 'left')
joint_rpvg_knownASE.head(3)
# Out:
#                          Name_1                        Name_2  ClusterID  \
# 0  transcript12583.chr10.nic_R1  transcript12583.chr10.nic_H1         20
# 1             TCONS_00020735_R1             TCONS_00020735_H1         20
# 2             TCONS_00020748_R1             TCONS_00020748_H1         20
#
#    HaplotypingProbability  ReadCount_1      TPM_1  ReadCount_2      TPM_2  \
# 0                     1.0   400.482380  50.293997    233.34355  29.312355
# 1                     1.0    14.922362   6.534654      0.00000   0.000000
# 2                     1.0     4.643587   0.997655     84.08753  18.065849
#
#                        trans     gene max         FC   MAX_value state
# 0  transcript12583.chr10.nic      NaN   T   1.716278  400.482380   NaN
# 1             TCONS_00020735  WASHC2A   T        inf   14.922362   NaN
# 2             TCONS_00020748  WASHC2A   T  18.108315   84.087530   NaN

# %%
joint_rpvg_knownASE[~joint_rpvg_knownASE['state'].isna()]
# Out:
#                  Name_1             Name_2  ClusterID  HaplotypingProbability  \
# 67    TCONS_00175647_R1  TCONS_00175647_R1       1397                0.720283
# 969   TCONS_00023278_R1  TCONS_00023278_H1        155                1.000000
# 970   TCONS_00023283_R1  TCONS_00023283_H1        155                1.000000
# 971   TCONS_00023281_R1  TCONS_00023281_H1        155                1.000000
# 972   TCONS_00023279_R1  TCONS_00023279_H1        155                1.000000
# 973   TCONS_00023280_R1  TCONS_00023280_H1        155                1.000000
# 1134  TCONS_00026443_H2  TCONS_00026443_H2        187                0.995278
# 1135  TCONS_00026444_H2  TCONS_00026444_H2        187                0.995278
# 1480  TCONS_00109160_H1  TCONS_00109160_H1       2045                1.000000
# 2103  TCONS_00125624_H2  TCONS_00125624_H2       1511                0.724249
# 2738  TCONS_00148078_R1  TCONS_00148078_H1       1004                1.000000
# 2752  TCONS_00150231_H1  TCONS_00150231_H2       1199                1.000000
# 3269  TCONS_00010395_R1  TCONS_00010395_H1       1046                0.500000
# 3270  TCONS_00010398_R1  TCONS_00010398_H1       1046                0.500000
# 3457  TCONS_00009311_H1  TCONS_00009311_H1        657                1.000000
# 3520  TCONS_00173922_R1  TCONS_00173922_R1       1400                1.000000
# 3567  TCONS_00056023_R1  TCONS_00056023_H1       2394                0.500000
#
#       ReadCount_1       TPM_1  ReadCount_2       TPM_2           trans  \
# 67       0.844897    3.279558     0.844897    3.279558  TCONS_00175647
# 969    422.470910  241.810110   442.851260  253.475230  TCONS_00023278
# 970    153.184910  166.803150   170.897510  186.090410  TCONS_00023283
# 971     64.398497   43.994902    69.595190   47.545109  TCONS_00023281
# 972      0.000000    0.000000    44.006452   34.197827  TCONS_00023279
# 973      0.000000    0.000000    16.536629   10.531766  TCONS_00023280
# 1134  1617.899200  511.913680  1617.899200  511.913680  TCONS_00026443
# 1135  1020.078900  323.447220  1020.078900  323.447220  TCONS_00026444
# 1480     0.500000    0.202471     0.500000    0.202471  TCONS_00109160
# 2103     2.896886    1.123643     2.896886    1.123643  TCONS_00125624
# 2738     1.997110    0.297699     4.002890    0.434656  TCONS_00148078
# 2752     6.839905    0.745162     4.160095    0.469839  TCONS_00150231
# 3269    10.802079    7.703804    10.802079    7.703804  TCONS_00010395
# 3270     8.169511    5.817023     8.169511    5.817023  TCONS_00010398
# 3457     1.645957    0.712741     1.645957    0.712741  TCONS_00009311
# 3520     1.500000    0.307402     1.500000    0.307402  TCONS_00173922
# 3567     0.500000    0.032963     0.500000    0.032963  TCONS_00056023
#
#         gene max        FC    MAX_value           state
# 67     FASTK   T  1.000000     0.844897  allelespecific
# 969     PAOX   T  1.048241   442.851260  allelespecific
# 970     PAOX   T  1.115629   170.897510  allelespecific
# 971     PAOX   T  1.080696    69.595190  allelespecific
# 972     PAOX   T       inf    44.006452  allelespecific
# 973     PAOX   T       inf    16.536629  allelespecific
# 1134    LDB1   T  1.000000  1617.899200  allelespecific
# 1135    LDB1   T  1.000000  1020.078900  allelespecific
# 1480  CYP1B1   T  1.000000     0.500000  allelespecific
# 2103  DGCR6L   T  1.000000     2.896886  allelespecific
# 2738    GAB1   T  2.004341     4.002890  allelespecific
# 2752   ERAP2   T  1.644170     6.839905  allelespecific
# 3269   FUCA1   T  1.000000    10.802079  allelespecific
# 3270   FUCA1   T  1.000000     8.169511  allelespecific
# 3457   PEX10   T  1.000000     1.645957  allelespecific
# 3520    PON2   T  1.000000     1.500000  allelespecific
# 3567   SMOC1   T  1.000000     0.500000  allelespecific

# %% [markdown]
# ## Plot

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
# %matplotlib notebook
# %matplotlib widget
# %matplotlib inline
# Out:
# Warning: Cannot change to a different GUI toolkit: widget. Using notebook instead.

# %%
gene_to_plt = "ZNF248"

# %%
by_transcript = rpvg_gene_max[rpvg_gene_max['gene'] == gene_to_plt]
by_transcript.index = by_transcript.trans
by_transcript.head()
# Out:
#                            Name_1             Name_2  ClusterID  \
# trans
# TCONS_00024377  TCONS_00024377_H1  TCONS_00024377_H1        250
# TCONS_00024356  TCONS_00024356_H1  TCONS_00024356_H2        250
# TCONS_00024394  TCONS_00024394_H1  TCONS_00024394_H1        250
# TCONS_00024374  TCONS_00024374_H1  TCONS_00024374_H1        250
# TCONS_00024381  TCONS_00024381_H1  TCONS_00024381_H1        250
#
#                 HaplotypingProbability  ReadCount_1       TPM_1  ReadCount_2  \
# trans
# TCONS_00024377                     1.0   644.802870  102.390860    644.80287
# TCONS_00024356                     1.0    16.298647    3.818694     32.65372
# TCONS_00024394                     1.0   134.590040   36.886219    134.59004
# TCONS_00024374                     1.0     0.000000    0.000000      0.00000
# TCONS_00024381                     1.0   191.314380   55.770293    191.31438
#
#                      TPM_2           trans    gene max        FC  MAX_value
# trans
# TCONS_00024377  102.390860  TCONS_00024377  ZNF248   T  1.000000  644.80287
# TCONS_00024356    7.650609  TCONS_00024356  ZNF248   T  2.003462   32.65372
# TCONS_00024394   36.886219  TCONS_00024394  ZNF248   T  1.000000  134.59004
# TCONS_00024374    0.000000  TCONS_00024374  ZNF248   T       NaN    0.00000
# TCONS_00024381   55.770293  TCONS_00024381  ZNF248   T  1.000000  191.31438

# %%
list(by_transcript.index)
# Out:
# ['TCONS_00024377',
#  'TCONS_00024356',
#  'TCONS_00024394',
#  'TCONS_00024374',
#  'TCONS_00024381']

# %%
by_transcript['log_totalExp']  = np.log10(by_transcript['TPM_1'] + by_transcript['TPM_2']+1)
by_transcript = by_transcript.sort_values(by = "log_totalExp", ascending=True)
by_transcript_totalExp = by_transcript[['log_totalExp']]
by_transcript_totalExp.index = by_transcript['trans']
by_transcript_totalExp.head()
# Out:
# /tmp/ipykernel_138690/1219754040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   by_transcript['log_totalExp']  = np.log10(by_transcript['TPM_1'] + by_transcript['TPM_2']+1)
#                 log_totalExp
# trans
# TCONS_00024374      0.000000
# TCONS_00024356      1.095842
# TCONS_00024394      1.873742
# TCONS_00024381      2.051309
# TCONS_00024377      2.313407

# %%
totalMAX=max(by_transcript_totalExp['log_totalExp'])+0.1

# %%
by_transcript['ReadCount_1_prob']  = by_transcript['ReadCount_1'] / (by_transcript['ReadCount_1'] + by_transcript['ReadCount_2'] ) * 100
by_transcript['ReadCount_2_prob']  = by_transcript['ReadCount_2'] / (by_transcript['ReadCount_1'] + by_transcript['ReadCount_2'] ) * 100
by_transcript_prob = by_transcript[['ReadCount_1_prob','ReadCount_2_prob']]

# %%
ax1 = by_transcript_prob.plot.barh()

# %%
ax2 = by_transcript_totalExp.plot.barh(color="green")

# %%
by_transcript_prob
# Out:
#                 ReadCount_1_prob  ReadCount_2_prob
# trans
# TCONS_00024374               NaN               NaN
# TCONS_00024356         33.294911         66.705089
# TCONS_00024394         50.000000         50.000000
# TCONS_00024381         50.000000         50.000000
# TCONS_00024377         50.000000         50.000000

# %%
import numpy as np
by_transcript_FC = pd.DataFrame(np.log10( (by_transcript_prob['ReadCount_1_prob'] + 1) / (by_transcript_prob['ReadCount_2_prob'] + 1)))
by_transcript_FC.columns = ['logFC']
by_transcript_FC = by_transcript_FC.reset_index()
by_transcript_FC['logFC'] = by_transcript_FC['logFC'].fillna(0)
by_transcript_FC.head(6)
# Out:
#             trans     logFC
# 0  TCONS_00024374  0.000000
# 1  TCONS_00024356 -0.295392
# 2  TCONS_00024394  0.000000
# 3  TCONS_00024381  0.000000
# 4  TCONS_00024377  0.000000

# %%
# Plotting
plt.scatter(by_transcript_FC['logFC'], by_transcript_FC['trans'], label='Data points', color='blue')
plt.plot(by_transcript_FC['logFC'], by_transcript_FC['trans'], label='Connected line', color='red', linestyle='-', marker='o')

# %%
by_transcript_FC['logFC']
# Out:
# 0    0.000000
# 1   -0.295392
# 2    0.000000
# 3    0.000000
# 4    0.000000
# Name: logFC, dtype: float64

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Create a gridspec with one row and three columns
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(6, 3), frameon=False, constrained_layout=True, gridspec_kw={'width_ratios': [2, 1, 1]})

# Plot data on each subplot
by_transcript_prob.plot.barh(ax=ax1)
by_transcript_totalExp.plot.barh(ax=ax2, color = "green")

ax3.scatter(by_transcript_FC['logFC'], by_transcript_FC['trans'], label='Data points', color='blue')
ax3.plot(by_transcript_FC['logFC'], by_transcript_FC['trans'], label='Connected line', color='red', linestyle='-', marker='o')

# Set x-axis limits for each subplot
ax1.set_xlim(0, 100)
ax2.set_xlim(0, totalMAX)
ax3.set_xlim(-max(abs(by_transcript_FC['logFC']))-0.5, max(abs(by_transcript_FC['logFC']))+0.5)

# Set the background color of each subplot to white
ax1.set_facecolor('white')
ax2.set_facecolor('white')
ax3.set_facecolor('white')

# Set the background color of the figure to white
fig.set_facecolor('white')

# Set the grid color to light gray
ax1.grid(color='lightgray', linestyle='--')
ax2.grid(color='lightgray', linestyle='--')
ax3.grid(color='lightgray', linestyle='--')

# Add x-axis for each subplot
ax1.set_xlabel('Proprtion of Exp')
ax2.set_xlabel('Total Exp')
ax3.set_xlabel('FC')
ax3.set_ylabel('Transcripts')

fig.suptitle(gene_to_plt, fontsize=16, y=1.08)

ax1.legend().set_visible(False)
ax2.legend().set_visible(False)
ax3.legend().set_visible(False)


plt.show()

# %%
transName="/gpfs/gsfs11/users/kimj75/00.Files/references/hg002/hg002v101/fiberseq/geneTrans.name"
transName = pd.read_csv(transName, sep='\t', header=None)
transName.columns = ['trans','gene']
transName.head(7)
# Out:
#             trans          gene
# 0  TCONS_00000001  LOC124905335
# 1  TCONS_00000002     LINC01409
# 2  TCONS_00000003     LINC01409
# 3  TCONS_00000004  LOC124903817
# 4  TCONS_00000005        FAM87B
# 5  TCONS_00000006     LINC01128
# 6  TCONS_00000010     LINC01128

# %%
methyl_hst="/gpfs/gsfs11/users/kimj75/00.Files/references/hg002/hg002v101/fiberseq/FDR-wide-peaks.matToCHM13.hst.bed"
methyl_hst = pd.read_csv(methyl_hst, sep='\t', header=None)
methyl_hst.columns = ['CHM13_chr','CHM13_start','CHM13_End',
                     'trans','Gene1','CHM13_chr_ori','CHM13_start_ori','CHM13_End_ori',
                     'MAT']
methyl_hst.head(3)
# Out:
#   CHM13_chr  CHM13_start  CHM13_End                      trans        Gene1  \
# 0      chr1    154998370  155023314  transcript62227.chr1.nnic  XLOC_001499
# 1      chr1    160132277  160158230             TCONS_00014993  XLOC_003870
# 2      chr1    205949085  205998488             TCONS_00007762  XLOC_001993
#
#   CHM13_chr_ori  CHM13_start_ori  CHM13_End_ori  \
# 0          chr1        154999432      154999607
# 1          chr1        160134481      160134651
# 2          chr1        205967984      205968201
#
#                                  MAT
# 0  chr1_MATERNAL:150697855-150698030
# 1  chr1_MATERNAL:155830323-155830493
# 2  chr1_MATERNAL:201600559-201600776

# %%
tab = methyl_hst.merge(transName, on = "trans")
tab= tab[['MAT','gene']]
tab.head(3)
# Out:
#                                  MAT      gene
# 0  chr1_MATERNAL:155830323-155830493      F11R
# 1  chr1_MATERNAL:201600559-201600776  MAPKAPK2
# 2  chr1_MATERNAL:201614101-201614324  MAPKAPK2

# %%
selected_rows.head(3)
# Out:
#                             Name_1                        Name_2  ClusterID  \
# 7634             TCONS_00019335_H1             TCONS_00019335_H2        114
# 4912             TCONS_00022257_H1             TCONS_00022257_H2         12
# 8331  transcript19906.chr10.nic_H1  transcript19906.chr10.nic_H2         28
#
#       HaplotypingProbability  ReadCount_1      TPM_1  ReadCount_2  TPM_2  \
# 7634                     1.0   1427.15130  408.16844          0.0    0.0
# 4912                     1.0   1082.46690  372.89102          0.0    0.0
# 8331                     1.0    709.99839  172.74028          0.0    0.0
#
#                           trans   gene max   FC   MAX_value
# 7634             TCONS_00019335   FBH1   T  inf  1427.15130
# 4912             TCONS_00022257  LZTS2   T  inf  1082.46690
# 8331  transcript19906.chr10.nic    NaN   T  inf   709.99839

# %%
selected_rows_wGene = tab.merge(selected_rows, on="gene", how="right")
selected_rows_wGene.head(3)
# Out:
#                               MAT  gene             Name_1             Name_2  \
# 0  chr10_MATERNAL:5895266-5895422  FBH1  TCONS_00019335_H1  TCONS_00019335_H2
# 1  chr10_MATERNAL:5895266-5895422  FBH1  TCONS_00019335_H1  TCONS_00019335_H2
# 2  chr10_MATERNAL:5895266-5895422  FBH1  TCONS_00019335_H1  TCONS_00019335_H2
#
#    ClusterID  HaplotypingProbability  ReadCount_1      TPM_1  ReadCount_2  \
# 0        114                     1.0    1427.1513  408.16844          0.0
# 1        114                     1.0    1427.1513  408.16844          0.0
# 2        114                     1.0    1427.1513  408.16844          0.0
#
#    TPM_2           trans max   FC  MAX_value
# 0    0.0  TCONS_00019335   T  inf  1427.1513
# 1    0.0  TCONS_00019335   T  inf  1427.1513
# 2    0.0  TCONS_00019335   T  inf  1427.1513

# %%
from io import StringIO
selected_rows_wGene = selected_rows_wGene[selected_rows_wGene['MAT'].notna()]
selected_rows_wGene.groupby('gene')['MAT'].apply(lambda x: ','.join(x)).reset_index()
# Out:
#           gene                                                MAT
# 0          ADK  chr10_MATERNAL:76276354-76276516,chr10_MATERNA...
# 1        ASB13                     chr10_MATERNAL:5656621-5656899
# 2        ASCC1  chr10_MATERNAL:74105754-74105877,chr10_MATERNA...
# 3        CERS6                  chr2_MATERNAL:168374687-168374917
# 4       CHST15  chr10_MATERNAL:126072675-126072827,chr10_MATER...
# 5    DDX11-AS1                   chr12_MATERNAL:30928100-30928268
# 6      DNAJB12  chr10_MATERNAL:74307702-74307858,chr10_MATERNA...
# 7        ESYT2  chr7_MATERNAL:160375686-160375902,chr7_MATERNA...
# 8         F11R                  chr1_MATERNAL:155830323-155830493
# 9      FAM167A  chr8_MATERNAL:11013234-11013463,chr8_MATERNAL:...
# 10        FBH1  chr10_MATERNAL:5895266-5895422,chr10_MATERNAL:...
# 11        FRS2  chr12_MATERNAL:69680453-69680575,chr12_MATERNA...
# 12        GRK5                 chr10_MATERNAL:121332339-121332514
# 13         HK1                   chr10_MATERNAL:71307611-71307890
# 14     ITPRID2  chr2_MATERNAL:181809083-181809326,chr2_MATERNA...
# 15   LINC02642  chr10_MATERNAL:7449995-7450174,chr10_MATERNAL:...
# 16        LIPA                   chr10_MATERNAL:91265360-91265503
# 17      LRRC27  chr10_MATERNAL:134427896-134428051,chr10_MATER...
# 18       LZTS2  chr10_MATERNAL:103046406-103046578,chr10_MATER...
# 19    MAPKAPK2  chr1_MATERNAL:201600559-201600776,chr1_MATERNA...
# 20      MLLT10                   chr10_MATERNAL:21542012-21542158
# 21       NDST2  chr10_MATERNAL:75773968-75774178,chr10_MATERNA...
# 22       NT5C2  chr10_MATERNAL:105183932-105184106,chr10_MATER...
# 23  NUTM2B-AS1  chr10_MATERNAL:81864345-81864536,chr10_MATERNA...
# 24        ORC2  chr2_MATERNAL:200826296-200826422,chr2_MATERNA...
# 25        PAOX  chr10_MATERNAL:135502275-135502386,chr10_MATER...
# 26      SEMA4G                 chr10_MATERNAL:103018026-103018429
# 27     SLC41A2                 chr12_MATERNAL:105058092-105058308
# 28    STAMBPL1                   chr10_MATERNAL:90947082-90947230
# 29      STK32C                 chr10_MATERNAL:134325261-134325445
# 30    SVIL-AS1  chr10_MATERNAL:29477761-29477918,chr10_MATERNA...
# 31      TMED10  chr14_MATERNAL:77102074-77102256,chr14_MATERNA...
# 32       TRAF3  chr14_MATERNAL:104788968-104789135,chr14_MATER...
# 33        VAV2  chr9_MATERNAL:139164856-139165050,chr9_MATERNA...
# 34       VSTM4  chr10_MATERNAL:51014572-51015014,chr10_MATERNA...
# 35       VTI1A  chr10_MATERNAL:114541529-114541842,chr10_MATER...
# 36      ZFYVE1  chr14_MATERNAL:75001412-75001613,chr14_MATERNA...
# 37     ZMYND11  chr10_MATERNAL:171642-171792,chr10_MATERNAL:17...
# 38      ZNF165                    chr6_MATERNAL:28033425-28033634
# 39      ZNF248                   chr10_MATERNAL:37882470-37882594
