# %% [markdown]
# # import modules

# %%
import pandas as pd
from Bio import SeqIO
from Bio import Entrez
from Bio.Blast import NCBIXML
from Bio.Blast import NCBIWWW
from Bio import ExPASy
import biomart 
import swan_vis as swan
import cv2
from IPython.display import display, Image
import pandas as pd
# %matplotlib inline
import swan_vis as swan

# %%
## Load graph
# load up a saved SwanGraph from a pickle file
sg = swan.read('/data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/07.hg002v1.0.1/swanv2.p.p')

# %%
import os

os.getcwd()
os.chdir('/data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/07.hg002v1.0.1/')

# %% [markdown]
# ## Plot

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
# %matplotlib notebook
# %matplotlib widget
# %matplotlib inline

# %%
rpvg_gene_max = pd.read_csv('/data/Phillippy/projects/HG002_Masseq/06.pantranscriptome/07.hg002v1.0.1/05.quantification/hg002v101.allGene.isoquantModel.rpvg_joint.max.txt',
          sep='\t')
rpvg_gene_max

# %% [raw]
# iso = 'transcript10401.chr10.nnic'
# gene_to_plt = list(rpvg_gene_max.loc[rpvg_gene_max['trans'] == iso, "geneName"])[0]
# by_transcript = rpvg_gene_max[rpvg_gene_max['geneName'] == gene_to_plt]
# by_transcript.index = by_transcript.trans
# by_transcript

# %%
gene_to_plt = 'MFSD13A'
by_transcript = rpvg_gene_max[rpvg_gene_max['geneName'] == gene_to_plt]
by_transcript.index = by_transcript.trans
by_transcript

# %%
list(by_transcript.index)
# Out:
# ['TCONS_00026541',
#  'TCONS_00026548',
#  'TCONS_00026558',
#  'TCONS_00026540',
#  'TCONS_00026539',
#  'TCONS_00026538',
#  'TCONS_00026534',
#  'TCONS_00026551',
#  'TCONS_00026556',
#  'TCONS_00026532',
#  'TCONS_00026544',
#  'TCONS_00026536',
#  'TCONS_00026537',
#  'TCONS_00026550',
#  'TCONS_00026555',
#  'TCONS_00026543',
#  'TCONS_00026535',
#  'TCONS_00026533',
#  'TCONS_00026547']

# %%
by_transcript['log_totalExp']  = np.log10(by_transcript['TPM_1'] + by_transcript['TPM_2']+1)
by_transcript = by_transcript.sort_values(by = "log_totalExp", ascending=True)
by_transcript_totalExp = by_transcript[['log_totalExp']]
by_transcript_totalExp.index = by_transcript['trans']
by_transcript_totalExp
# Out:
#                 log_totalExp
# trans
# TCONS_00026547      0.000000
# TCONS_00026548      0.000000
# TCONS_00026535      0.000000
# TCONS_00026540      0.000000
# TCONS_00026539      0.000000
# TCONS_00026543      0.000000
# TCONS_00026555      0.000000
# TCONS_00026556      0.000000
# TCONS_00026550      0.000000
# TCONS_00026544      0.000000
# TCONS_00026537      0.708320
# TCONS_00026538      0.936363
# TCONS_00026541      1.234096
# TCONS_00026533      1.445502
# TCONS_00026532      1.458571
# TCONS_00026558      1.505582
# TCONS_00026534      1.655432
# TCONS_00026551      1.742642
# TCONS_00026536      2.258505

# %%
totalMAX=max(by_transcript_totalExp['log_totalExp'])+0.1

# %%
by_transcript['TPM_1_prob']  = by_transcript['TPM_1'] / (by_transcript['TPM_1'] + by_transcript['TPM_2'] ) * 100
by_transcript['TPM_2_prob']  = by_transcript['TPM_2'] / (by_transcript['TPM_1'] + by_transcript['TPM_2'] ) * 100
by_transcript_prob = by_transcript[['TPM_1_prob','TPM_2_prob']]

# %%
ax1 = by_transcript_prob.plot.barh()

# %%
ax2 = by_transcript_totalExp.plot.barh(color="green")

# %%
import numpy as np
by_transcript_FC = pd.DataFrame(np.log10( (by_transcript_prob['TPM_1_prob'] + 1) / (by_transcript_prob['TPM_2_prob'] + 1)))
by_transcript_FC.columns = ['logFC']
by_transcript_FC = by_transcript_FC.reset_index()
by_transcript_FC['logFC'] = by_transcript_FC['logFC'].fillna(0)
by_transcript_FC.head(6)
# Out:
#             trans  logFC
# 0  TCONS_00026547    0.0
# 1  TCONS_00026548    0.0
# 2  TCONS_00026535    0.0
# 3  TCONS_00026540    0.0
# 4  TCONS_00026539    0.0
# 5  TCONS_00026543    0.0

# %%
# Plotting
plt.scatter(by_transcript_FC['logFC'], by_transcript_FC['trans'], label='Data points', color='blue')
plt.plot(by_transcript_FC['logFC'], by_transcript_FC['trans'], label='Connected line', color='red', linestyle='-', marker='o')

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Create a gridspec with one row and three columns
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(6, 3), frameon=False, constrained_layout=True, gridspec_kw={'width_ratios': [2, 1, 1]})

# Plot data on each subplot
by_transcript_prob.plot.barh(ax=ax1)
by_transcript_totalExp.plot.barh(ax=ax2, color = "green")

ax3.scatter(by_transcript_FC['logFC'], by_transcript_FC['trans'], label='Data points', color='blue')
ax3.plot(by_transcript_FC['logFC'], by_transcript_FC['trans'], label='Connected line', color='red', linestyle='-', marker='o')

# Set x-axis limits for each subplotd
ax1.set_xlim(0, 100)
ax2.set_xlim(0, totalMAX)
ax3.set_xlim(-max(abs(by_transcript_FC['logFC']))-0.5, max(abs(by_transcript_FC['logFC']))+0.5)

# Set the background color of each subplot to white
ax1.set_facecolor('white')
ax2.set_facecolor('white')
ax3.set_facecolor('white')

# Set the background color of the figure to white
fig.set_facecolor('white')

# Set the grid color to light gray
ax1.grid(color='lightgray', linestyle='--')
ax2.grid(color='lightgray', linestyle='--')
ax3.grid(color='lightgray', linestyle='--')

# Add x-axis for each subplot
ax1.set_xlabel('Proprtion of Exp')
ax2.set_xlabel('Total Exp')
ax3.set_xlabel('FC')
ax3.set_ylabel('Transcripts')

fig.suptitle(gene_to_plt, fontsize=16, y=1.08)

ax1.legend().set_visible(False)
ax2.legend().set_visible(False)
ax3.legend().set_visible(False)


plt.show()

# %%
order_trans = by_transcript_totalExp.index.tolist()
order_trans.reverse()
order_trans
# Out:
# ['TCONS_00026536',
#  'TCONS_00026551',
#  'TCONS_00026534',
#  'TCONS_00026558',
#  'TCONS_00026532',
#  'TCONS_00026533',
#  'TCONS_00026541',
#  'TCONS_00026538',
#  'TCONS_00026537',
#  'TCONS_00026544',
#  'TCONS_00026550',
#  'TCONS_00026556',
#  'TCONS_00026555',
#  'TCONS_00026543',
#  'TCONS_00026539',
#  'TCONS_00026540',
#  'TCONS_00026535',
#  'TCONS_00026548',
#  'TCONS_00026547']

# %%
sg.plot_each_transcript(order_trans, browser=True, prefix = 'figures/trans')
# Out:
# Saving transcript path graph for TCONS_00026536 as figures/trans_browser_TCONS_00026536_path.png
# Saving transcript path graph for TCONS_00026551 as figures/trans_browser_TCONS_00026551_path.png
# Saving transcript path graph for TCONS_00026534 as figures/trans_browser_TCONS_00026534_path.png
# Saving transcript path graph for TCONS_00026558 as figures/trans_browser_TCONS_00026558_path.png
# Saving transcript path graph for TCONS_00026532 as figures/trans_browser_TCONS_00026532_path.png
# Saving transcript path graph for TCONS_00026533 as figures/trans_browser_TCONS_00026533_path.png
# Saving transcript path graph for TCONS_00026541 as figures/trans_browser_TCONS_00026541_path.png
# Saving transcript path graph for TCONS_00026538 as figures/trans_browser_TCONS_00026538_path.png
# Saving transcript path graph for TCONS_00026537 as figures/trans_browser_TCONS_00026537_path.png
# Saving transcript path graph for TCONS_00026544 as figures/trans_browser_TCONS_00026544_path.png
# Saving transcript path graph for TCONS_00026550 as figures/trans_browser_TCONS_00026550_path.png
# Saving transcript path graph for TCONS_00026556 as figures/trans_browser_TCONS_00026556_path.png
# Saving transcript path graph for TCONS_00026555 as figures/trans_browser_TCONS_00026555_path.png
# Saving transcript path graph for TCONS_00026543 as figures/trans_browser_TCONS_00026543_path.png
# Saving transcript path graph for TCONS_00026539 as figures/trans_browser_TCONS_00026539_path.png
# Saving transcript path graph for TCONS_00026540 as figures/trans_browser_TCONS_00026540_path.png
# Saving transcript path graph for TCONS_00026535 as figures/trans_browser_TCONS_00026535_path.png
# Saving transcript path graph for TCONS_00026548 as figures/trans_browser_TCONS_00026548_path.png
# Saving transcript path graph for TCONS_00026547 as figures/trans_browser_TCONS_00026547_path.png

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Create a gridspec with one row and three columns
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(6, 3), frameon=False, constrained_layout=True, gridspec_kw={'width_ratios': [2, 1, 1]})

# Plot data on each subplot
by_transcript_prob.plot.barh(ax=ax1)
by_transcript_totalExp.plot.barh(ax=ax2, color = "green")

ax3.scatter(by_transcript_FC['logFC'], by_transcript_FC['trans'], label='Data points', color='blue')
ax3.plot(by_transcript_FC['logFC'], by_transcript_FC['trans'], label='Connected line', color='red', linestyle='-', marker='o')

# Set x-axis limits for each subplotd
ax1.set_xlim(0, 100)
ax2.set_xlim(0, totalMAX)
ax3.set_xlim(-max(abs(by_transcript_FC['logFC']))-0.5, max(abs(by_transcript_FC['logFC']))+0.5)

# Set the background color of each subplot to white
ax1.set_facecolor('white')
ax2.set_facecolor('white')
ax3.set_facecolor('white')

# Set the background color of the figure to white
fig.set_facecolor('white')

# Set the grid color to light gray
ax1.grid(color='lightgray', linestyle='--')
ax2.grid(color='lightgray', linestyle='--')
ax3.grid(color='lightgray', linestyle='--')

# Add x-axis for each subplot
ax1.set_xlabel('Proprtion of Exp')
ax2.set_xlabel('Total Exp')
ax3.set_xlabel('FC')
ax3.set_ylabel('Transcripts')

fig.suptitle(gene_to_plt, fontsize=16, y=1.08)

ax1.legend().set_visible(False)
ax2.legend().set_visible(False)
ax3.legend().set_visible(False)


plt.show()

# %%
import glob
import matplotlib.pyplot as plt
from PIL import Image as PILImage

# Create a figure and axis
fig, ax = plt.subplots()

# Define the offset for overlapping
offset_x = 0
offset_y = 50
new_width=1000
new_height = 200
# Iterate over each transformation
for i, trans in enumerate(order_trans):
    imageName = glob.glob('figures/*_browser_'+trans+'*.png')[0]
    img = PILImage.open(imageName)
    img = img.resize((new_width, new_height))  # Replace new_width and new_height with your desired dimensions
    
    # Adjust the position of the image based on the offset
    x_offset = i * offset_x
    y_offset = i * offset_y
    ax.imshow(img, alpha=1, extent=[-x_offset, new_width - x_offset, -y_offset, new_height - y_offset])

# Set the limits of the plot
ax.set_xlim(-offset_x * len(order_trans), new_width)
ax.set_ylim(-offset_y * len(order_trans), new_height)

# Turn off axis
ax.axis('off')

# Show the overlapped images
plt.show()
